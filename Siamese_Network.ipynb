# %%
# Import libraries
import tensorflow
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.python.keras.utils.vis_utils import plot_model
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageFont, ImageDraw
import random

# %%
# Creating pairs of images
def create_pairs(x, digit_indices):
    pairs = []
    labels = []
    n = min([len(digit_indices[d]) for d in range(10)]) - 1
    
    for d in range(10):
        for i in range(n):
            z1, z2 = digit_indices[d][i], digit_indices[d][i + 1]
            pairs += [[x[z1], x[z2]]]
            inc = random.randrange(1, 10)
            dn = (d + inc) % 10
            z1, z2 = digit_indices[d][i], digit_indices[dn][i]
            pairs += [[x[z1], x[z2]]]
            labels += [1, 0]
            
    return np.array(pairs), np.array(labels)


def create_pairs_on_set(images, labels):
    
    digit_indices = [np.where(labels == i)[0] for i in range(10)]
    pairs, y = create_pairs(images, digit_indices)
    y = y.astype('float32')
    
    return pairs, y


def show_image(image):
    plt.figure()
    plt.imshow(image)
    plt.colorbar()
    plt.grid(False)
    plt.show()

# %%
# Import the dataset
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

train_images = train_images / 255.0
test_images = test_images / 255.0

tr_pairs, tr_y = create_pairs_on_set(train_images, train_labels)
ts_pairs, ts_y = create_pairs_on_set(test_images, test_labels)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
this_pair = 8

show_image(tr_pairs[this_pair][0])
show_image(tr_pairs[this_pair][1])

print(tr_y[this_pair])
# Out:
# 1.0

# %%
# Custom neural network
def initialize_base_network():
    input = Input(shape=(28,28,), name="base_input")
    x = Flatten(name="flatten_input")(input)
    x = Dense(128, activation='relu', name="first_base_dense")(x)
    x = Dropout(0.1, name="first_dropout")(x)
    x = Dense(128, activation='relu', name="second_base_dense")(x)
    x = Dropout(0.1, name="second_dropout")(x)
    x = Dense(128, activation='relu', name="third_base_dense")(x)

    return Model(inputs=input, outputs=x)


def euclidean_distance(vects):
    x, y = vects
    sum_square = K.sum(K.square(x - y), axis=1, keepdims=True)
    return K.sqrt(K.maximum(sum_square, K.epsilon()))


def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
base_network = initialize_base_network()
plot_model(base_network, show_shapes=True, show_layer_names=True)

# %%
input_a = Input(shape=(28,28,), name="left_input")
vect_output_a = base_network(input_a)

input_b = Input(shape=(28,28,), name="right_input")
vect_output_b = base_network(input_b)

output = Lambda(euclidean_distance, name="output_layer", output_shape=eucl_dist_output_shape)([vect_output_a, vect_output_b])

model = Model([input_a, input_b], output)

plot_model(model, show_shapes=True, show_layer_names=True, to_file='outer-model.png')

# %%
# Custom loss function
from tensorflow.keras.losses import Loss
class ContrastiveLoss(Loss):

  margin = 0
  
  def __init__(self,margin):
    super().__init__()
    self.margin = margin

  def call(self,y_true,y_pred):
    square_pred = K.square(y_pred)
    margin_square = K.square(K.maximum(self.margin - y_pred,0))
    return K.mean(y_true*square_pred + (1-y_true)*margin_square)

# %%
# Training our model
adam = Adam()
model.compile(loss=ContrastiveLoss(margin=1), optimizer=adam,metrics=['accuracy'])
history = model.fit([tr_pairs[:,0], tr_pairs[:,1]], tr_y, epochs=100, batch_size=128, validation_data=([ts_pairs[:,0], ts_pairs[:,1]], ts_y))
# Out:
# Epoch 1/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0399 - accuracy: 0.0530 - val_loss: 0.0663 - val_accuracy: 0.0909
# Epoch 2/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0389 - accuracy: 0.0520 - val_loss: 0.0672 - val_accuracy: 0.0924
# Epoch 3/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0399 - accuracy: 0.0529 - val_loss: 0.0666 - val_accuracy: 0.0920
# Epoch 4/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0390 - accuracy: 0.0511 - val_loss: 0.0681 - val_accuracy: 0.0928
# Epoch 5/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0397 - accuracy: 0.0528 - val_loss: 0.0669 - val_accuracy: 0.0912
# Epoch 6/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0395 - accuracy: 0.0528 - val_loss: 0.0685 - val_accuracy: 0.0912
# Epoch 7/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0405 - accuracy: 0.0532 - val_loss: 0.0676 - val_accuracy: 0.0915
# Epoch 8/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0394 - accuracy: 0.0524 - val_loss: 0.0676 - val_accuracy: 0.0926
# Epoch 9/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0387 - accuracy: 0.0514 - val_loss: 0.0676 - val_accuracy: 0.0911
# Epoch 10/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0401 - accuracy: 0.0535 - val_loss: 0.0673 - val_accuracy: 0.0916
# Epoch 11/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0395 - accuracy: 0.0525 - val_loss: 0.0664 - val_accuracy: 0.0908
# Epoch 12/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0397 - accuracy: 0.0528 - val_loss: 0.0684 - val_accuracy: 0.0920
# Epoch 13/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0395 - accuracy: 0.0527 - val_loss: 0.0681 - val_accuracy: 0.0925
# Epoch 14/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0396 - accuracy: 0.0520 - val_loss: 0.0684 - val_accuracy: 0.0929
# Epoch 15/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0397 - accuracy: 0.0524 - val_loss: 0.0658 - val_accuracy: 0.0910
# Epoch 16/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0386 - accuracy: 0.0516 - val_loss: 0.0683 - val_accuracy: 0.0942
# Epoch 17/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0384 - accuracy: 0.0512 - val_loss: 0.0678 - val_accuracy: 0.0913
# Epoch 18/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0396 - accuracy: 0.0523 - val_loss: 0.0667 - val_accuracy: 0.0896
# Epoch 19/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0389 - accuracy: 0.0516 - val_loss: 0.0682 - val_accuracy: 0.0917
# Epoch 20/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0388 - accuracy: 0.0514 - val_loss: 0.0690 - val_accuracy: 0.0932
# Epoch 21/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0387 - accuracy: 0.0507 - val_loss: 0.0668 - val_accuracy: 0.0922
# Epoch 22/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0388 - accuracy: 0.0511 - val_loss: 0.0685 - val_accuracy: 0.0935
# Epoch 23/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0387 - accuracy: 0.0511 - val_loss: 0.0671 - val_accuracy: 0.0921
# Epoch 24/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0385 - accuracy: 0.0508 - val_loss: 0.0687 - val_accuracy: 0.0920
# Epoch 25/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0397 - accuracy: 0.0515 - val_loss: 0.0677 - val_accuracy: 0.0918
# Epoch 26/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0395 - accuracy: 0.0518 - val_loss: 0.0663 - val_accuracy: 0.0923
# Epoch 27/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0386 - accuracy: 0.0509 - val_loss: 0.0693 - val_accuracy: 0.0929
# Epoch 28/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0381 - accuracy: 0.0510 - val_loss: 0.0687 - val_accuracy: 0.0947
# Epoch 29/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0391 - accuracy: 0.0520 - val_loss: 0.0686 - val_accuracy: 0.0926
# Epoch 30/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0382 - accuracy: 0.0506 - val_loss: 0.0680 - val_accuracy: 0.0936
# Epoch 31/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0387 - accuracy: 0.0507 - val_loss: 0.0683 - val_accuracy: 0.0910
# Epoch 32/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0390 - accuracy: 0.0514 - val_loss: 0.0680 - val_accuracy: 0.0948
# Epoch 33/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0380 - accuracy: 0.0505 - val_loss: 0.0684 - val_accuracy: 0.0943
# Epoch 34/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0384 - accuracy: 0.0513 - val_loss: 0.0674 - val_accuracy: 0.0931
# Epoch 35/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0386 - accuracy: 0.0515 - val_loss: 0.0693 - val_accuracy: 0.0937
# Epoch 36/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0378 - accuracy: 0.0499 - val_loss: 0.0673 - val_accuracy: 0.0928
# Epoch 37/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0384 - accuracy: 0.0503 - val_loss: 0.0675 - val_accuracy: 0.0925
# Epoch 38/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0373 - accuracy: 0.0492 - val_loss: 0.0684 - val_accuracy: 0.0933
# Epoch 39/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0382 - accuracy: 0.0505 - val_loss: 0.0687 - val_accuracy: 0.0934
# Epoch 40/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0383 - accuracy: 0.0503 - val_loss: 0.0686 - val_accuracy: 0.0926
# Epoch 41/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0383 - accuracy: 0.0498 - val_loss: 0.0684 - val_accuracy: 0.0924
# Epoch 42/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0376 - accuracy: 0.0497 - val_loss: 0.0678 - val_accuracy: 0.0935
# Epoch 43/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0376 - accuracy: 0.0490 - val_loss: 0.0687 - val_accuracy: 0.0940
# Epoch 44/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0378 - accuracy: 0.0504 - val_loss: 0.0681 - val_accuracy: 0.0930
# Epoch 45/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0378 - accuracy: 0.0505 - val_loss: 0.0679 - val_accuracy: 0.0944
# Epoch 46/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0376 - accuracy: 0.0496 - val_loss: 0.0677 - val_accuracy: 0.0932
# Epoch 47/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0381 - accuracy: 0.0511 - val_loss: 0.0687 - val_accuracy: 0.0930
# Epoch 48/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0382 - accuracy: 0.0509 - val_loss: 0.0682 - val_accuracy: 0.0938
# Epoch 49/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0378 - accuracy: 0.0501 - val_loss: 0.0694 - val_accuracy: 0.0941
# Epoch 50/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0382 - accuracy: 0.0500 - val_loss: 0.0667 - val_accuracy: 0.0914
# Epoch 51/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0380 - accuracy: 0.0507 - val_loss: 0.0684 - val_accuracy: 0.0942
# Epoch 52/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0375 - accuracy: 0.0493 - val_loss: 0.0680 - val_accuracy: 0.0920
# Epoch 53/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0373 - accuracy: 0.0489 - val_loss: 0.0698 - val_accuracy: 0.0971
# Epoch 54/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0376 - accuracy: 0.0502 - val_loss: 0.0691 - val_accuracy: 0.0946
# Epoch 55/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0372 - accuracy: 0.0493 - val_loss: 0.0685 - val_accuracy: 0.0937
# Epoch 56/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0375 - accuracy: 0.0493 - val_loss: 0.0682 - val_accuracy: 0.0962
# Epoch 57/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0380 - accuracy: 0.0509 - val_loss: 0.0683 - val_accuracy: 0.0935
# Epoch 58/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0383 - accuracy: 0.0509 - val_loss: 0.0679 - val_accuracy: 0.0937
# Epoch 59/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0372 - accuracy: 0.0486 - val_loss: 0.0696 - val_accuracy: 0.0937
# Epoch 60/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0373 - accuracy: 0.0492 - val_loss: 0.0691 - val_accuracy: 0.0957
# Epoch 61/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0371 - accuracy: 0.0492 - val_loss: 0.0679 - val_accuracy: 0.0916
# Epoch 62/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0375 - accuracy: 0.0500 - val_loss: 0.0681 - val_accuracy: 0.0948
# Epoch 63/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0374 - accuracy: 0.0503 - val_loss: 0.0693 - val_accuracy: 0.0921
# Epoch 64/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0377 - accuracy: 0.0503 - val_loss: 0.0681 - val_accuracy: 0.0945
# Epoch 65/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0378 - accuracy: 0.0494 - val_loss: 0.0705 - val_accuracy: 0.0933
# Epoch 66/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0397 - accuracy: 0.0507 - val_loss: 0.0695 - val_accuracy: 0.0943
# Epoch 67/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0385 - accuracy: 0.0507 - val_loss: 0.0681 - val_accuracy: 0.0915
# Epoch 68/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0368 - accuracy: 0.0490 - val_loss: 0.0689 - val_accuracy: 0.0936
# Epoch 69/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0375 - accuracy: 0.0496 - val_loss: 0.0690 - val_accuracy: 0.0928
# Epoch 70/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0374 - accuracy: 0.0492 - val_loss: 0.0673 - val_accuracy: 0.0913
# Epoch 71/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0376 - accuracy: 0.0504 - val_loss: 0.0686 - val_accuracy: 0.0926
# Epoch 72/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0370 - accuracy: 0.0487 - val_loss: 0.0674 - val_accuracy: 0.0920
# Epoch 73/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0366 - accuracy: 0.0477 - val_loss: 0.0706 - val_accuracy: 0.0958
# Epoch 74/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0370 - accuracy: 0.0485 - val_loss: 0.0687 - val_accuracy: 0.0925
# Epoch 75/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0370 - accuracy: 0.0485 - val_loss: 0.0681 - val_accuracy: 0.0930
# Epoch 76/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0370 - accuracy: 0.0486 - val_loss: 0.0704 - val_accuracy: 0.0963
# Epoch 77/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0375 - accuracy: 0.0505 - val_loss: 0.0707 - val_accuracy: 0.0947
# Epoch 78/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0362 - accuracy: 0.0480 - val_loss: 0.0686 - val_accuracy: 0.0918
# Epoch 79/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0369 - accuracy: 0.0487 - val_loss: 0.0695 - val_accuracy: 0.0936
# Epoch 80/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0375 - accuracy: 0.0489 - val_loss: 0.0695 - val_accuracy: 0.0934
# Epoch 81/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0371 - accuracy: 0.0489 - val_loss: 0.0678 - val_accuracy: 0.0928
# Epoch 82/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0371 - accuracy: 0.0491 - val_loss: 0.0686 - val_accuracy: 0.0927
# Epoch 83/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0365 - accuracy: 0.0483 - val_loss: 0.0684 - val_accuracy: 0.0936
# Epoch 84/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0374 - accuracy: 0.0498 - val_loss: 0.0692 - val_accuracy: 0.0971
# Epoch 85/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0366 - accuracy: 0.0476 - val_loss: 0.0708 - val_accuracy: 0.0959
# Epoch 86/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0372 - accuracy: 0.0494 - val_loss: 0.0696 - val_accuracy: 0.0950
# Epoch 87/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0374 - accuracy: 0.0499 - val_loss: 0.0688 - val_accuracy: 0.0947
# Epoch 88/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0371 - accuracy: 0.0490 - val_loss: 0.0672 - val_accuracy: 0.0913
# Epoch 89/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0365 - accuracy: 0.0474 - val_loss: 0.0681 - val_accuracy: 0.0933
# Epoch 90/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0364 - accuracy: 0.0488 - val_loss: 0.0691 - val_accuracy: 0.0932
# Epoch 91/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0364 - accuracy: 0.0476 - val_loss: 0.0685 - val_accuracy: 0.0939
# Epoch 92/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0365 - accuracy: 0.0479 - val_loss: 0.0679 - val_accuracy: 0.0926
# Epoch 93/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0367 - accuracy: 0.0483 - val_loss: 0.0677 - val_accuracy: 0.0930
# Epoch 94/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0369 - accuracy: 0.0493 - val_loss: 0.0691 - val_accuracy: 0.0944
# Epoch 95/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0368 - accuracy: 0.0492 - val_loss: 0.0715 - val_accuracy: 0.0945
# Epoch 96/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0364 - accuracy: 0.0476 - val_loss: 0.0692 - val_accuracy: 0.0934
# Epoch 97/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0378 - accuracy: 0.0491 - val_loss: 0.0686 - val_accuracy: 0.0941
# Epoch 98/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0374 - accuracy: 0.0491 - val_loss: 0.0708 - val_accuracy: 0.0968
# Epoch 99/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0359 - accuracy: 0.0474 - val_loss: 0.0708 - val_accuracy: 0.0960
# Epoch 100/100
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0367 - accuracy: 0.0483 - val_loss: 0.0696 - val_accuracy: 0.0937

# %%
def visualize_images():
    plt.rc('image', cmap='gray_r')
    plt.rc('grid', linewidth=0)
    plt.rc('xtick', top=False, bottom=False, labelsize='large')
    plt.rc('ytick', left=False, right=False, labelsize='large')
    plt.rc('axes', facecolor='F8F8F8', titlesize="large", edgecolor='white')
    plt.rc('text', color='a8151a')
    plt.rc('figure', facecolor='F0F0F0')

def display_images(left, right, predictions, labels, title, n):
    plt.figure(figsize=(17,3))
    plt.title(title)
    plt.yticks([])
    plt.xticks([])
    plt.grid(None)
    left = np.reshape(left, [n, 28, 28])
    left = np.swapaxes(left, 0, 1)
    left = np.reshape(left, [28, 28*n])
    plt.imshow(left)
    plt.figure(figsize=(17,3))
    plt.yticks([])
    plt.xticks([28*x+14 for x in range(n)], predictions)
    for i,t in enumerate(plt.gca().xaxis.get_ticklabels()):
        if predictions[i] > 0.5: t.set_color('red') 
    plt.grid(None)
    right = np.reshape(right, [n, 28, 28])
    right = np.swapaxes(right, 0, 1)
    right = np.reshape(right, [28, 28*n])
    plt.imshow(right)

# %%
y_pred_train = np.squeeze(y_pred_train)
indexes = np.random.choice(len(y_pred_train), size=10)
display_images(tr_pairs[:, 0][indexes], tr_pairs[:, 1][indexes], y_pred_train[indexes], tr_y[indexes], "clothes and their dissimilarity", 10)
